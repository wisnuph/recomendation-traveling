# %%
#import library

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
raw_data = pd.read_csv('eco_rating.csv')
data = raw_data[:800]
data
# Out:
#      user_id  place_id  user_rating
# 0          1        28            2
# 1          1        86            4
# 2          1        94            4
# 3          1       146            3
# 4          2        17            2
# ..       ...       ...          ...
# 795      145       170            3
# 796      145        13            3
# 797      145        35            2
# 798      146        40            5
# 799      146        57            3
#
# [800 rows x 3 columns]

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42, shuffle=True)

# %%
# ini data training (80%) sebanyak 640 data

train
# Out:
#      user_id  place_id  user_rating
# 264       49       147            3
# 615      111       118            3
# 329       61       105            3
# 342       63        93            4
# 394       72       155            5
# ..       ...       ...          ...
# 71        13        54            3
# 106       21        90            2
# 270       50       162            2
# 435       79        75            5
# 102       20        97            5
#
# [640 rows x 3 columns]

# %%
# ini data test (20%) sebanyak 160 data

test
# Out:
#      user_id  place_id  user_rating
# 696      127         3            3
# 667      121        76            2
# 63        12        47            4
# 533       97        27            5
# 66        12       156            3
# ..       ...       ...          ...
# 589      106        62            4
# 798      146        40            5
# 744      136       129            5
# 513       93        64            3
# 670      122       166            3
#
# [160 rows x 3 columns]

# %%
#menghitung total jumlah user dan item yang unique

number_users = data['user_id'].nunique()
number_items = data['place_id'].nunique()

number_users, number_items
# Out:
# (146, 181)

# %%
#create model NCF

user_input = tf.keras.layers.Input(shape=(1,))
item_input = tf.keras.layers.Input(shape=(1,))

user_embedding = tf.keras.layers.Embedding(number_users + 10, 16)(user_input)
item_embedding = tf.keras.layers.Embedding(number_items + 10, 16)(item_input)

user_flat = tf.keras.layers.Flatten()(user_embedding)
item_flat = tf.keras.layers.Flatten()(item_embedding)

concat = tf.keras.layers.Concatenate()([user_flat, item_flat])
dropout_1 = tf.keras.layers.Dropout(0.5)(concat)
dense_1 = tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.01))(dropout_1)
dropout_2 = tf.keras.layers.Dropout(0.3)(dense_1)
dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.01))(dropout_2)
output = tf.keras.layers.Dense(1)(dense_2)

model = tf.keras.models.Model(inputs=[user_input, item_input], outputs=output)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 1)]                  0         []
#
#  input_4 (InputLayer)        [(None, 1)]                  0         []
#
#  embedding_2 (Embedding)     (None, 1, 16)                2496      ['input_3[0][0]']
#
#  embedding_3 (Embedding)     (None, 1, 16)                3056      ['input_4[0][0]']
#
#  flatten_2 (Flatten)         (None, 16)                   0         ['embedding_2[0][0]']
#
#  flatten_3 (Flatten)         (None, 16)                   0         ['embedding_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32)                   0         ['flatten_2[0][0]',
#  )                                                                   'flatten_3[0][0]']
#
#  dropout_2 (Dropout)         (None, 32)                   0         ['concatenate_1[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  4224      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['dropout_3[0][0]']
#
#  dense_5 (Dense)             (None, 1)                    65        ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 18097 (70.69 KB)
# Trainable params: 18097 (70.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#model compiler with optimizer and loss mse

model.compile(optimizer='rmsprop', loss='mean_squared_error')

# %%
#training data with model

model.fit([train['user_id'], train['place_id']], train['user_rating'], epochs=100, batch_size=32, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/100
# 16/16 - 2s - loss: 12.4589 - val_loss: 9.0308 - 2s/epoch - 94ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 7.0879 - val_loss: 3.9458 - 77ms/epoch - 5ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 3.0148 - val_loss: 2.0850 - 74ms/epoch - 5ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 2.0596 - val_loss: 1.9604 - 59ms/epoch - 4ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 1.8914 - val_loss: 1.8391 - 75ms/epoch - 5ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 1.6839 - val_loss: 1.8351 - 61ms/epoch - 4ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 1.6325 - val_loss: 1.7128 - 59ms/epoch - 4ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 1.4907 - val_loss: 1.6312 - 58ms/epoch - 4ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 1.3563 - val_loss: 1.6123 - 74ms/epoch - 5ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 1.3263 - val_loss: 1.6947 - 59ms/epoch - 4ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 1.2319 - val_loss: 1.5689 - 78ms/epoch - 5ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 1.1637 - val_loss: 1.6477 - 74ms/epoch - 5ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 1.1055 - val_loss: 1.5730 - 72ms/epoch - 4ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 1.0739 - val_loss: 1.6233 - 74ms/epoch - 5ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 1.0101 - val_loss: 1.6139 - 76ms/epoch - 5ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.9711 - val_loss: 1.6180 - 59ms/epoch - 4ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.8889 - val_loss: 1.6358 - 59ms/epoch - 4ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.9224 - val_loss: 1.6554 - 77ms/epoch - 5ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.8515 - val_loss: 1.6513 - 61ms/epoch - 4ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.8866 - val_loss: 1.7178 - 73ms/epoch - 5ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.8065 - val_loss: 1.6867 - 72ms/epoch - 5ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.8005 - val_loss: 1.6647 - 74ms/epoch - 5ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.7526 - val_loss: 1.7347 - 60ms/epoch - 4ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.7635 - val_loss: 1.7676 - 61ms/epoch - 4ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.7362 - val_loss: 1.6198 - 59ms/epoch - 4ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.7009 - val_loss: 1.6472 - 72ms/epoch - 4ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.6860 - val_loss: 1.6792 - 71ms/epoch - 4ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.6819 - val_loss: 1.6265 - 62ms/epoch - 4ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.6451 - val_loss: 1.7433 - 68ms/epoch - 4ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.6614 - val_loss: 1.6638 - 60ms/epoch - 4ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.7015 - val_loss: 1.6338 - 68ms/epoch - 4ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.6423 - val_loss: 1.7152 - 72ms/epoch - 5ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.6123 - val_loss: 1.8768 - 73ms/epoch - 5ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.6056 - val_loss: 1.6746 - 75ms/epoch - 5ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.6220 - val_loss: 1.6597 - 57ms/epoch - 4ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.5931 - val_loss: 1.7074 - 73ms/epoch - 5ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.5931 - val_loss: 1.8706 - 76ms/epoch - 5ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.5914 - val_loss: 1.8777 - 60ms/epoch - 4ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.6025 - val_loss: 1.7710 - 57ms/epoch - 4ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.5881 - val_loss: 1.6614 - 80ms/epoch - 5ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.5811 - val_loss: 1.7479 - 72ms/epoch - 5ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.5729 - val_loss: 1.7363 - 78ms/epoch - 5ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.5574 - val_loss: 1.7989 - 84ms/epoch - 5ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.5694 - val_loss: 1.7333 - 60ms/epoch - 4ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.5762 - val_loss: 1.7452 - 74ms/epoch - 5ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.5572 - val_loss: 1.7258 - 73ms/epoch - 5ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.5253 - val_loss: 1.6908 - 74ms/epoch - 5ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.5611 - val_loss: 1.6901 - 63ms/epoch - 4ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.5288 - val_loss: 1.9039 - 59ms/epoch - 4ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.5395 - val_loss: 1.8034 - 71ms/epoch - 4ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.5424 - val_loss: 1.8162 - 75ms/epoch - 5ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 0.5352 - val_loss: 1.8044 - 75ms/epoch - 5ms/step
# Epoch 53/100
# 16/16 - 0s - loss: 0.5219 - val_loss: 1.7166 - 71ms/epoch - 4ms/step
# Epoch 54/100
# 16/16 - 0s - loss: 0.5078 - val_loss: 1.8837 - 59ms/epoch - 4ms/step
# Epoch 55/100
# 16/16 - 0s - loss: 0.5259 - val_loss: 1.8597 - 75ms/epoch - 5ms/step
# Epoch 56/100
# 16/16 - 0s - loss: 0.5295 - val_loss: 1.8089 - 79ms/epoch - 5ms/step
# Epoch 57/100
# 16/16 - 0s - loss: 0.5055 - val_loss: 1.8360 - 66ms/epoch - 4ms/step
# Epoch 58/100
# 16/16 - 0s - loss: 0.5006 - val_loss: 1.9078 - 74ms/epoch - 5ms/step
# Epoch 59/100
# 16/16 - 0s - loss: 0.4968 - val_loss: 1.7706 - 73ms/epoch - 5ms/step
# Epoch 60/100
# 16/16 - 0s - loss: 0.4941 - val_loss: 1.9428 - 57ms/epoch - 4ms/step
# Epoch 61/100
# 16/16 - 0s - loss: 0.5156 - val_loss: 1.9398 - 72ms/epoch - 5ms/step
# Epoch 62/100
# 16/16 - 0s - loss: 0.5035 - val_loss: 1.8938 - 61ms/epoch - 4ms/step
# Epoch 63/100
# 16/16 - 0s - loss: 0.5102 - val_loss: 1.8900 - 73ms/epoch - 5ms/step
# Epoch 64/100
# 16/16 - 0s - loss: 0.4911 - val_loss: 1.7964 - 74ms/epoch - 5ms/step
# Epoch 65/100
# 16/16 - 0s - loss: 0.4915 - val_loss: 1.8866 - 60ms/epoch - 4ms/step
# Epoch 66/100
# 16/16 - 0s - loss: 0.5127 - val_loss: 1.8203 - 59ms/epoch - 4ms/step
# Epoch 67/100
# 16/16 - 0s - loss: 0.5003 - val_loss: 1.9493 - 58ms/epoch - 4ms/step
# Epoch 68/100
# 16/16 - 0s - loss: 0.4631 - val_loss: 1.8583 - 63ms/epoch - 4ms/step
# Epoch 69/100
# 16/16 - 0s - loss: 0.4897 - val_loss: 1.8449 - 63ms/epoch - 4ms/step
# Epoch 70/100
# 16/16 - 0s - loss: 0.4913 - val_loss: 1.8783 - 56ms/epoch - 4ms/step
# Epoch 71/100
# 16/16 - 0s - loss: 0.4661 - val_loss: 2.0139 - 57ms/epoch - 4ms/step
# Epoch 72/100
# 16/16 - 0s - loss: 0.4951 - val_loss: 1.9021 - 87ms/epoch - 5ms/step
# Epoch 73/100
# 16/16 - 0s - loss: 0.4552 - val_loss: 1.9098 - 73ms/epoch - 5ms/step
# Epoch 74/100
# 16/16 - 0s - loss: 0.4689 - val_loss: 1.7951 - 74ms/epoch - 5ms/step
# Epoch 75/100
# 16/16 - 0s - loss: 0.4923 - val_loss: 1.8075 - 58ms/epoch - 4ms/step
# Epoch 76/100
# 16/16 - 0s - loss: 0.5071 - val_loss: 1.9349 - 73ms/epoch - 5ms/step
# Epoch 77/100
# 16/16 - 0s - loss: 0.4686 - val_loss: 1.8093 - 72ms/epoch - 5ms/step
# Epoch 78/100
# 16/16 - 0s - loss: 0.4759 - val_loss: 2.0517 - 59ms/epoch - 4ms/step
# Epoch 79/100
# 16/16 - 0s - loss: 0.4869 - val_loss: 1.8229 - 60ms/epoch - 4ms/step
# Epoch 80/100
# 16/16 - 0s - loss: 0.4961 - val_loss: 1.9515 - 73ms/epoch - 5ms/step
# Epoch 81/100
# 16/16 - 0s - loss: 0.4730 - val_loss: 1.9531 - 61ms/epoch - 4ms/step
# Epoch 82/100
# 16/16 - 0s - loss: 0.4860 - val_loss: 1.7697 - 65ms/epoch - 4ms/step
# Epoch 83/100
# 16/16 - 0s - loss: 0.4935 - val_loss: 1.8776 - 72ms/epoch - 4ms/step
# Epoch 84/100
# 16/16 - 0s - loss: 0.4591 - val_loss: 1.8057 - 73ms/epoch - 5ms/step
# Epoch 85/100
# 16/16 - 0s - loss: 0.4657 - val_loss: 1.9830 - 74ms/epoch - 5ms/step
# Epoch 86/100
# 16/16 - 0s - loss: 0.4537 - val_loss: 1.8323 - 72ms/epoch - 5ms/step
# Epoch 87/100
# 16/16 - 0s - loss: 0.4528 - val_loss: 1.9523 - 61ms/epoch - 4ms/step
# Epoch 88/100
# 16/16 - 0s - loss: 0.4827 - val_loss: 1.8516 - 73ms/epoch - 5ms/step
# Epoch 89/100
# 16/16 - 0s - loss: 0.4587 - val_loss: 1.9705 - 73ms/epoch - 5ms/step
# Epoch 90/100
# 16/16 - 0s - loss: 0.4504 - val_loss: 1.8880 - 57ms/epoch - 4ms/step
# Epoch 91/100
# 16/16 - 0s - loss: 0.4748 - val_loss: 1.7883 - 76ms/epoch - 5ms/step
# Epoch 92/100
# 16/16 - 0s - loss: 0.4669 - val_loss: 1.9113 - 63ms/epoch - 4ms/step
# Epoch 93/100
# 16/16 - 0s - loss: 0.4615 - val_loss: 1.9237 - 60ms/epoch - 4ms/step
# Epoch 94/100
# 16/16 - 0s - loss: 0.4709 - val_loss: 1.8041 - 63ms/epoch - 4ms/step
# Epoch 95/100
# 16/16 - 0s - loss: 0.4790 - val_loss: 1.8404 - 61ms/epoch - 4ms/step
# Epoch 96/100
# 16/16 - 0s - loss: 0.4349 - val_loss: 1.9846 - 58ms/epoch - 4ms/step
# Epoch 97/100
# 16/16 - 0s - loss: 0.4604 - val_loss: 1.9671 - 60ms/epoch - 4ms/step
# Epoch 98/100
# 16/16 - 0s - loss: 0.4696 - val_loss: 1.9223 - 71ms/epoch - 4ms/step
# Epoch 99/100
# 16/16 - 0s - loss: 0.4585 - val_loss: 1.9720 - 73ms/epoch - 5ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 0.4475 - val_loss: 1.7883 - 75ms/epoch - 5ms/step

# %%
#evaluate model with test data - MAE

result_mae = model.evaluate([test['user_id'], test['place_id']], test['user_rating'])
print(f'MAE: {result_mae}')
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 1.6784
# MAE: 1.67837655544281

# %%
#predict data in row 801

raw_data_predict = raw_data.iloc[801]
user_id = raw_data_predict['user_id']
item_id = raw_data_predict['place_id']
rating = raw_data_predict['user_rating']

y_predict = model.predict([np.array([user_id]), np.array([item_id])])
print(f'\nNilai prediksi rating untuk USER_ID={user_id} dan ITEM_ID={item_id} adalah: {y_predict[0][0]} \ndengan data sebenarnya yaitu {rating}')
# Out:
# 1/1 [==============================] - 0s 113ms/step
#
# Nilai prediksi rating untuk USER_ID=146 dan ITEM_ID=114 adalah: 2.761202096939087
# dengan data sebenarnya yaitu 3

# %%
#Nilai MAE(Mean Absolute Error) dan RMSE

mae = mean_absolute_error([rating], y_predict.flatten())
print(f'MAE: {mae}')

rmse = np.sqrt(mean_squared_error([rating], y_predict.flatten()))
print(f'RMSE: {rmse}')
# Out:
# MAE: 0.23879790306091309
# RMSE: 0.23879790306091309
